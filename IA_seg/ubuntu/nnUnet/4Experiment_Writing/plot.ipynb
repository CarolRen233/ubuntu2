# %%
import SimpleITK as sitk
import numpy as np
from matplotlib import pyplot as plt 
import cv2

# %%
cta_image = 'D:/codes/mycodes/Tr0033.nii.gz'

# %% [raw]
# cta_nii = sitk.ReadImage(cta_image)
# #print (cta_nii)

# %%
#cta_np = sitk.GetArrayFromImage(cta_nii).astype(np.float32)

name = 'XJTr0247_bone_mip2'

cta_np = np.load('D:/zhongjian/cowtransfer/' + name + '.npz')[name[-9:]]

# %%
plt.imshow(cta_np,cmap='gray')
plt.axis('off')
plt.savefig(name+'.png',dpi=200,bbox_inches = 'tight')

# %%
plt.imshow(cta_np,cmap='gray')
cv2.imwrite(name + ".png",cta_np)
# Out:
# True

# %%
plt.imshow(cta_np[500:,70:450,315],cmap='gray')
cv2.imwrite("filename.png",cta_np[500:,70:450,315])
# Out:
# True

# %%
bone_np = np.clip(cta_np,200,800)
bone_np = (bone_np-200)/(800-200)*255

# %%
bone_np_y = np.max(bone_np,axis=1)
bone_np_x = np.max(bone_np,axis=2)

# %%
plt.imshow(bone_np_y,cmap='gray')
cv2.imwrite("bone_np_y.png",bone_np_y)
# Out:
# True

# %%
plt.imshow(bone_np_x,cmap='gray')
cv2.imwrite("bone_np_x.png",bone_np_x)
# Out:
# True

# %%
a = np.clip(cta_np,0,100)
a_ = (a-0)/(100)*255

# %%
plt.imshow(a_[500:,70:450,315],cmap='gray')
cv2.imwrite("0100_np_x.png",a_[500:,70:450,315])
# Out:
# True

# %%
b = np.clip(cta_np,100,200)
b_ = (b-100)/(100)*255

# %%
plt.imshow(b_[:,:,315],cmap='gray')
cv2.imwrite("1200_np_x.png",b_[500:,70:450,315])
# Out:
# True

# %%
bone_np = np.clip(cta_np,200,800)
bone_np = (bone_np-200)/(800-200)*255
plt.imshow(bone_np[:,:,315],cmap='gray')
cv2.imwrite("2008_np_x.png",bone_np[500:,70:450,315])
# Out:
# True
