# %%
import os,glob
import numpy as np
import SimpleITK as sitk
from math import fabs, copysign
from collections import OrderedDict
import shutil
from utils import *

# %%
data_file = '/mnt/f/data/CellPress1338'

# %%
data_list = sorted(os.listdir(os.path.join(data_file,'cta_img')))
print (len(data_list))
print (data_list[0])

ts_data_list = []
for name in data_list:
    if name.startswith('Ts'):
        ts_data_list.append(name)
print (ts_data_list)
# Out:
# 1338
# Tr0001.nii.gz
# ['Ts0001.nii.gz', 'Ts0002.nii.gz', 'Ts0003.nii.gz', 'Ts0004.nii.gz', 'Ts0005.nii.gz', 'Ts0006.nii.gz', 'Ts0007.nii.gz', 'Ts0008.nii.gz', 'Ts0009.nii.gz', 'Ts0010.nii.gz', 'Ts0011.nii.gz', 'Ts0012.nii.gz', 'Ts0013.nii.gz', 'Ts0014.nii.gz', 'Ts0015.nii.gz', 'Ts0016.nii.gz', 'Ts0017.nii.gz', 'Ts0018.nii.gz', 'Ts0019.nii.gz', 'Ts0020.nii.gz', 'Ts0021.nii.gz', 'Ts0022.nii.gz', 'Ts0023.nii.gz', 'Ts0024.nii.gz', 'Ts0025.nii.gz', 'Ts0026.nii.gz', 'Ts0027.nii.gz', 'Ts0028.nii.gz', 'Ts0029.nii.gz', 'Ts0030.nii.gz', 'Ts0031.nii.gz', 'Ts0032.nii.gz', 'Ts0033.nii.gz', 'Ts0034.nii.gz', 'Ts0035.nii.gz', 'Ts0036.nii.gz', 'Ts0037.nii.gz', 'Ts0038.nii.gz', 'Ts0039.nii.gz', 'Ts0040.nii.gz', 'Ts0041.nii.gz', 'Ts0042.nii.gz', 'Ts0043.nii.gz', 'Ts0044.nii.gz', 'Ts0045.nii.gz', 'Ts0046.nii.gz', 'Ts0047.nii.gz', 'Ts0048.nii.gz', 'Ts0049.nii.gz', 'Ts0050.nii.gz', 'Ts0051.nii.gz', 'Ts0052.nii.gz', 'Ts0053.nii.gz', 'Ts0054.nii.gz', 'Ts0055.nii.gz', 'Ts0056.nii.gz', 'Ts0057.nii.gz', 'Ts0058.nii.gz', 'Ts0059.nii.gz', 'Ts0060.nii.gz', 'Ts0061.nii.gz', 'Ts0062.nii.gz', 'Ts0063.nii.gz', 'Ts0064.nii.gz', 'Ts0065.nii.gz', 'Ts0066.nii.gz', 'Ts0067.nii.gz', 'Ts0068.nii.gz', 'Ts0069.nii.gz', 'Ts0070.nii.gz', 'Ts0071.nii.gz', 'Ts0072.nii.gz', 'Ts0073.nii.gz', 'Ts0074.nii.gz', 'Ts0075.nii.gz', 'Ts0076.nii.gz', 'Ts0077.nii.gz', 'Ts0078.nii.gz', 'Ts0079.nii.gz', 'Ts0080.nii.gz', 'Ts0081.nii.gz', 'Ts0082.nii.gz', 'Ts0083.nii.gz', 'Ts0084.nii.gz', 'Ts0085.nii.gz', 'Ts0086.nii.gz', 'Ts0087.nii.gz', 'Ts0088.nii.gz', 'Ts0089.nii.gz', 'Ts0090.nii.gz', 'Ts0091.nii.gz', 'Ts0092.nii.gz', 'Ts0093.nii.gz', 'Ts0094.nii.gz', 'Ts0095.nii.gz', 'Ts0096.nii.gz', 'Ts0097.nii.gz', 'Ts0098.nii.gz', 'Ts0099.nii.gz', 'Ts0100.nii.gz', 'Ts0101.nii.gz', 'Ts0102.nii.gz', 'Ts0103.nii.gz', 'Ts0104.nii.gz', 'Ts0105.nii.gz', 'Ts0106.nii.gz', 'Ts0107.nii.gz', 'Ts0108.nii.gz', 'Ts0109.nii.gz', 'Ts0110.nii.gz', 'Ts0111.nii.gz', 'Ts0112.nii.gz', 'Ts0113.nii.gz', 'Ts0114.nii.gz', 'Ts0115.nii.gz', 'Ts0116.nii.gz', 'Ts0117.nii.gz', 'Ts0118.nii.gz', 'Ts0119.nii.gz', 'Ts0120.nii.gz', 'Ts0121.nii.gz', 'Ts0122.nii.gz', 'Ts0123.nii.gz', 'Ts0124.nii.gz', 'Ts0125.nii.gz', 'Ts0126.nii.gz', 'Ts0127.nii.gz', 'Ts0128.nii.gz', 'Ts0129.nii.gz', 'Ts0130.nii.gz', 'Ts0131.nii.gz', 'Ts0132.nii.gz', 'Ts0133.nii.gz', 'Ts0134.nii.gz', 'Ts0135.nii.gz', 'Ts0136.nii.gz', 'Ts0137.nii.gz', 'Ts0138.nii.gz', 'Ts0139.nii.gz', 'Ts0140.nii.gz', 'Ts0141.nii.gz', 'Ts0142.nii.gz', 'Ts0143.nii.gz', 'Ts0144.nii.gz', 'Ts0145.nii.gz', 'Ts0146.nii.gz', 'Ts0147.nii.gz', 'Ts0148.nii.gz', 'Ts0149.nii.gz', 'Ts0150.nii.gz', 'Ts0151.nii.gz', 'Ts0152.nii.gz']

# %%
def generate_datainfo_csv(name,IA_voxels,slices):
 
    #name_attribute = ['id','slices','IA_voxels','IA_minz','IA_size']

    img = dict()
    img['id'] = name
    img['slices'] = slices
    img['IA_voxels'] = IA_voxels
    #img['IA_minz'] = IA_minz
    
    x = img['IA_voxels']
    y = copysign(fabs(x) ** (1 / 3), x)
    
    img['IA_size'] = int(y)
    
    return img

# %%
def generate_datainfo_pkl(name,cta,seg,data_file):

    property = OrderedDict()
    property['id'] = name
    property['ori_cta'] = os.path.join(data_file, 'cta_img', name + '.nii.gz')
    property['ori_seg'] = os.path.join(data_file, 'ane_seg', name + '.nii.gz')
    
    data_itk = cta
    property["original_size_of_raw_data"] = np.array(data_itk.GetSize())[[2, 1, 0]]
    property["original_spacing"] = np.array(data_itk.GetSpacing())[[2, 1, 0]]
    property["itk_origin"] = data_itk.GetOrigin()
    property["itk_spacing"] = data_itk.GetSpacing()
    property["itk_direction"] = data_itk.GetDirection()
    
    seg_np = sitk.GetArrayFromImage(seg).astype(np.int32)
    property['slices'] = seg_np.shape[0]
    property['IA_voxels'] = seg_np.sum()
    #IA_minz = np.min(np.where(seg_np==1)[0])
    #property['IA_minz'] = int(IA_minz)

    return property,property['IA_voxels'],property['slices']

# %%
csv_info_list = []
all_properties = OrderedDict()

for data in ts_data_list:
    name = data[:-7]
    print ('name:',name)
    cta_itk = sitk.ReadImage(os.path.join(data_file,'cta_img',data))
    seg_itk = sitk.ReadImage(os.path.join(data_file,'ane_seg',data))
    
    #pkl
    properti,IA_voxels,slices = generate_datainfo_pkl(name,cta_itk,seg_itk,data_file)
    #print ('IA_minz:',IA_minz)
    print ('slices:',slices)
    print ()
    all_properties[name] = properti
    
    
    #csv
    csv_info_list.append(generate_datainfo_csv(name,IA_voxels,slices))
# Out:
# name: Ts0001
# slices: 693
#
# name: Ts0002
# slices: 495
#
# name: Ts0003
# slices: 542
#
# name: Ts0004
# slices: 972
#
# name: Ts0005
# slices: 740
#
# name: Ts0006
# slices: 407
#
# name: Ts0007
# slices: 709
#
# name: Ts0008
# slices: 459
#
# name: Ts0009
# slices: 697
#
# name: Ts0010
# slices: 388
#
# name: Ts0011
# slices: 380
#
# name: Ts0012
# slices: 430
#
# name: Ts0013
# slices: 428
#
# name: Ts0014
# slices: 405
#
# name: Ts0015
# slices: 410
#
# name: Ts0016
# slices: 297
#
# name: Ts0017
# slices: 539
#
# name: Ts0018
# slices: 495
#
# name: Ts0019
# slices: 520
#
# name: Ts0020
# slices: 519
#
# name: Ts0021
# slices: 517
#
# name: Ts0022
# slices: 495
#
# name: Ts0023
# slices: 495
#
# name: Ts0024
# slices: 520
#
# name: Ts0025
# slices: 495
#
# name: Ts0026
# slices: 495
#
# name: Ts0027
# slices: 519
#
# name: Ts0028
# slices: 466
#
# name: Ts0029
# slices: 471
#
# name: Ts0030
# slices: 508
#
# name: Ts0031
# slices: 1310
#
# name: Ts0032
# slices: 501
#
# name: Ts0033
# slices: 856
#
# name: Ts0034
# slices: 560
#
# name: Ts0035
# slices: 495
#
# name: Ts0036
# slices: 495
#
# name: Ts0037
# slices: 550
#
# name: Ts0038
# slices: 533
#
# name: Ts0039
# slices: 510
#
# name: Ts0040
# slices: 674
#
# name: Ts0041
# slices: 685
#
# name: Ts0042
# slices: 495
#
# name: Ts0043
# slices: 495
#
# name: Ts0044
# slices: 716
#
# name: Ts0045
# slices: 483
#
# name: Ts0046
# slices: 798
#
# name: Ts0047
# slices: 856
#
# name: Ts0048
# slices: 883
#
# name: Ts0049
# slices: 545
#
# name: Ts0050
# slices: 736
#
# name: Ts0051
# slices: 851
#
# name: Ts0052
# slices: 699
#
# name: Ts0053
# slices: 400
#
# name: Ts0054
# slices: 848
#
# name: Ts0055
# slices: 406
#
# name: Ts0056
# slices: 417
#
# name: Ts0057
# slices: 387
#
# name: Ts0058
# slices: 814
#
# name: Ts0059
# slices: 847
#
# name: Ts0060
# slices: 856
#
# name: Ts0061
# slices: 428
#
# name: Ts0062
# slices: 416
#
# name: Ts0063
# slices: 386
#
# name: Ts0064
# slices: 398
#
# name: Ts0065
# slices: 814
#
# name: Ts0066
# slices: 856
#
# name: Ts0067
# slices: 832
#
# name: Ts0068
# slices: 911
#
# name: Ts0069
# slices: 856
#
# name: Ts0070
# slices: 526
#
# name: Ts0071
# slices: 907
#
# name: Ts0072
# slices: 495
#
# name: Ts0073
# slices: 856
#
# name: Ts0074
# slices: 829
#
# name: Ts0075
# slices: 455
#
# name: Ts0076
# slices: 911
#
# name: Ts0077
# slices: 856
#
# name: Ts0078
# slices: 513
#
# name: Ts0079
# slices: 813
#
# name: Ts0080
# slices: 495
#
# name: Ts0081
# slices: 856
#
# name: Ts0082
# slices: 856
#
# name: Ts0083
# slices: 866
#
# name: Ts0084
# slices: 498
#
# name: Ts0085
# slices: 916
#
# name: Ts0086
# slices: 501
#
# name: Ts0087
# slices: 856
#
# name: Ts0088
# slices: 911
#
# name: Ts0089
# slices: 495
#
# name: Ts0090
# slices: 529
#
# name: Ts0091
# slices: 370
#
# name: Ts0092
# slices: 386
#
# name: Ts0093
# slices: 265
#
# name: Ts0094
# slices: 353
#
# name: Ts0095
# slices: 373
#
# name: Ts0096
# slices: 353
#
# name: Ts0097
# slices: 383
#
# name: Ts0098
# slices: 395
#
# name: Ts0099
# slices: 353
#
# name: Ts0100
# slices: 461
#
# name: Ts0101
# slices: 358
#
# name: Ts0102
# slices: 353
#
# name: Ts0103
# slices: 416
#
# name: Ts0104
# slices: 398
#
# name: Ts0105
# slices: 395
#
# name: Ts0106
# slices: 393
#
# name: Ts0107
# slices: 420
#
# name: Ts0108
# slices: 402
#
# name: Ts0109
# slices: 243
#
# name: Ts0110
# slices: 886
#
# name: Ts0111
# slices: 398
#
# name: Ts0112
# slices: 384
#
# name: Ts0113
# slices: 368
#
# name: Ts0114
# slices: 393
#
# name: Ts0115
# slices: 415
#
# name: Ts0116
# slices: 391
#
# name: Ts0117
# slices: 385
#
# name: Ts0118
# slices: 437
#
# name: Ts0119
# slices: 378
#
# name: Ts0120
# slices: 476
#
# name: Ts0121
# slices: 353
#
# name: Ts0122
# slices: 383
#
# name: Ts0123
# slices: 414
#
# name: Ts0124
# slices: 360
#
# name: Ts0125
# slices: 393
#
# name: Ts0126
# slices: 348
#
# name: Ts0127
# slices: 414
#
# name: Ts0128
# slices: 366
#
# name: Ts0129
# slices: 353
#
# name: Ts0130
# slices: 498
#
# name: Ts0131
# slices: 365
#
# name: Ts0132
# slices: 975
#
# name: Ts0133
# slices: 353
#
# name: Ts0134
# slices: 408
#
# name: Ts0135
# slices: 451
#
# name: Ts0136
# slices: 433
#
# name: Ts0137
# slices: 783
#
# name: Ts0138
# slices: 375
#
# name: Ts0139
# slices: 405
#
# name: Ts0140
# slices: 493
#
# name: Ts0141
# slices: 413
#
# name: Ts0142
# slices: 353
#
# name: Ts0143
# slices: 353
#
# name: Ts0144
# slices: 353
#
# name: Ts0145
# slices: 220
#
# name: Ts0146
# slices: 748
#
# name: Ts0147
# slices: 353
#
# name: Ts0148
# slices: 699
#
# name: Ts0149
# slices: 699
#
# name: Ts0150
# slices: 643
#
# name: Ts0151
# slices: 492
#
# name: Ts0152
# slices: 536

# %%
# save csv
name_attribute = ['id','slices','IA_voxels','IA_size']
save_csv(csv_info_list,'All_CellPress1338_info.csv',name_attribute)


# save pkl
save_pickle(all_properties,'All_CellPress1338_info.pkl')

# %% [raw]
# shutil.copyfile('All_CellPress1338_info.csv',os.path.join(data_file,'All_Data_Info.csv'))
# shutil.copyfile('All_CellPress1338_info.pkl',os.path.join(data_file,'All_Data_Info.pkl'))
#
# shutil.copyfile('All_CellPress1338_info.pkl',os.path.join('/home/ubuntu/codes/radiology/2HeadCut','All_Data_Info.pkl'))
