# %%
import os,glob
import numpy as np
import SimpleITK as sitk
from math import fabs, copysign
from collections import OrderedDict
import shutil
from utils import *

# %%
data_file = '/media/ubuntu/Seagate Expansion Drive/IACTA/CellPress1338/external/B'

# %%
data_list = sorted(os.listdir(os.path.join(data_file,'cta_img')))
print (len(data_list))
print (data_list[0])
# Out:
# 67
# ExtB0001.nii.gz

# %%
def generate_datainfo_csv(name,IA_voxels,IA_minz,slices):
 
    #name_attribute = ['id','slices','IA_voxels','IA_minz','IA_size']

    img = dict()
    img['id'] = name
    img['slices'] = slices
    img['IA_voxels'] = IA_voxels
    img['IA_minz'] = IA_minz
    
    x = img['IA_voxels']
    y = copysign(fabs(x) ** (1 / 3), x)
    
    img['IA_size'] = int(y)
    
    return img

# %%
def generate_datainfo_pkl(name,cta,seg,data_file):

    property = OrderedDict()
    property['id'] = name
    property['ori_cta'] = os.path.join(data_file, 'cta_img', name + '.nii.gz')
    property['ori_seg'] = os.path.join(data_file, 'ane_seg', name + '.nii.gz')
    
    data_itk = cta
    property["original_size_of_raw_data"] = np.array(data_itk.GetSize())[[2, 1, 0]]
    property["original_spacing"] = np.array(data_itk.GetSpacing())[[2, 1, 0]]
    property["itk_origin"] = data_itk.GetOrigin()
    property["itk_spacing"] = data_itk.GetSpacing()
    property["itk_direction"] = data_itk.GetDirection()
    
    seg_np = sitk.GetArrayFromImage(seg).astype(np.int32)
    property['slices'] = seg_np.shape[0]
    property['IA_voxels'] = seg_np.sum()
    try:
        IA_minz = np.min(np.where(seg_np==1)[0])
    except:
        IA_minz = -1
    property['IA_minz'] = int(IA_minz)

    return property,property['IA_voxels'],property['IA_minz'],property['slices']

# %%
csv_info_list = []
all_properties = OrderedDict()

for data in data_list:
    name = data[:-7]
    print ('name:',name)
    cta_itk = sitk.ReadImage(os.path.join(data_file,'cta_img',data))
    seg_itk = sitk.ReadImage(os.path.join(data_file,'ane_seg',data))
    
    #pkl
    properti,IA_voxels,IA_minz,slices = generate_datainfo_pkl(name,cta_itk,seg_itk,data_file)
    print ('IA_minz:',IA_minz)
    print ('slices:',slices)
    print ()
    all_properties[name] = properti
    
    
    #csv
    csv_info_list.append(generate_datainfo_csv(name,IA_voxels,IA_minz,slices))
# Out:
# name: ExtB0001
# IA_minz: 541
# slices: 785
#
# name: ExtB0002
# IA_minz: 435
# slices: 679
#
# name: ExtB0003
# IA_minz: 513
# slices: 709
#
# name: ExtB0004
# IA_minz: 479
# slices: 695
#
# name: ExtB0005
# IA_minz: -1
# slices: 770
#
# name: ExtB0006
# IA_minz: 584
# slices: 818
#
# name: ExtB0007
# IA_minz: -1
# slices: 787
#
# name: ExtB0008
# IA_minz: 542
# slices: 796
#
# name: ExtB0009
# IA_minz: -1
# slices: 816
#
# name: ExtB0010
# IA_minz: 699
# slices: 913
#
# name: ExtB0011
# IA_minz: 638
# slices: 851
#
# name: ExtB0012
# IA_minz: 650
# slices: 907
#
# name: ExtB0013
# IA_minz: 240
# slices: 465
#
# name: ExtB0014
# IA_minz: -1
# slices: 770
#
# name: ExtB0015
# IA_minz: 541
# slices: 805
#
# name: ExtB0016
# IA_minz: 461
# slices: 718
#
# name: ExtB0017
# IA_minz: 701
# slices: 836
#
# name: ExtB0018
# IA_minz: 421
# slices: 672
#
# name: ExtB0019
# IA_minz: -1
# slices: 1140
#
# name: ExtB0020
# IA_minz: 567
# slices: 785
#
# name: ExtB0021
# IA_minz: 449
# slices: 728
#
# name: ExtB0022
# IA_minz: 317
# slices: 538
#
# name: ExtB0023
# IA_minz: 527
# slices: 750
#
# name: ExtB0024
# IA_minz: -1
# slices: 810
#
# name: ExtB0025
# IA_minz: 494
# slices: 756
#
# name: ExtB0026
# IA_minz: 487
# slices: 715
#
# name: ExtB0027
# IA_minz: 466
# slices: 711
#
# name: ExtB0028
# IA_minz: 582
# slices: 809
#
# name: ExtB0029
# IA_minz: -1
# slices: 770
#
# name: ExtB0030
# IA_minz: -1
# slices: 750
#
# name: ExtB0031
# IA_minz: 465
# slices: 696
#
# name: ExtB0032
# IA_minz: 485
# slices: 746
#
# name: ExtB0033
# IA_minz: 355
# slices: 615
#
# name: ExtB0034
# IA_minz: -1
# slices: 810
#
# name: ExtB0035
# IA_minz: 535
# slices: 792
#
# name: ExtB0036
# IA_minz: 494
# slices: 731
#
# name: ExtB0037
# IA_minz: 637
# slices: 878
#
# name: ExtB0038
# IA_minz: 265
# slices: 492
#
# name: ExtB0039
# IA_minz: -1
# slices: 770
#
# name: ExtB0040
# IA_minz: 589
# slices: 799
#
# name: ExtB0041
# IA_minz: 133
# slices: 387
#
# name: ExtB0042
# IA_minz: 123
# slices: 377
#
# name: ExtB0043
# IA_minz: 430
# slices: 660
#
# name: ExtB0044
# IA_minz: -1
# slices: 1209
#
# name: ExtB0045
# IA_minz: 501
# slices: 766
#
# name: ExtB0046
# IA_minz: -1
# slices: 770
#
# name: ExtB0047
# IA_minz: -1
# slices: 770
#
# name: ExtB0048
# IA_minz: -1
# slices: 770
#
# name: ExtB0049
# IA_minz: -1
# slices: 789
#
# name: ExtB0050
# IA_minz: 572
# slices: 799
#
# name: ExtB0051
# IA_minz: -1
# slices: 736
#
# name: ExtB0052
# IA_minz: -1
# slices: 790
#
# name: ExtB0053
# IA_minz: -1
# slices: 824
#
# name: ExtB0054
# IA_minz: -1
# slices: 819
#
# name: ExtB0055
# IA_minz: 524
# slices: 744
#
# name: ExtB0056
# IA_minz: 460
# slices: 708
#
# name: ExtB0057
# IA_minz: 546
# slices: 748
#
# name: ExtB0058
# IA_minz: 265
# slices: 511
#
# name: ExtB0059
# IA_minz: 174
# slices: 410
#
# name: ExtB0060
# IA_minz: 574
# slices: 843
#
# name: ExtB0061
# IA_minz: 147
# slices: 368
#
# name: ExtB0062
# IA_minz: 293
# slices: 524
#
# name: ExtB0063
# IA_minz: 183
# slices: 398
#
# name: ExtB0064
# IA_minz: 463
# slices: 670
#
# name: ExtB0065
# IA_minz: -1
# slices: 815
#
# name: ExtB0066
# IA_minz: -1
# slices: 1117
#
# name: ExtB0067
# IA_minz: -1
# slices: 1044

# %%
# save csv
name_attribute = ['id','slices','IA_voxels','IA_minz','IA_size']
save_csv(csv_info_list,'external_B_All_Data_Info.csv',name_attribute)


# save pkl
save_pickle(all_properties,'external_B_All_Data_Info.pkl')
